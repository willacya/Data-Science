# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.max_columns = 100

# %%
world_food_facts = pd.read_csv("FoodFacts.csv")
# Out:
# C:\Users\Director UYE\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (0,3,5,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
world_food_facts.head(2)
# Out:
#                  code                                                url  \
# 0  000000000000012866  http://world-en.openfoodfacts.org/product/0000...
# 1       0000000024600  http://world-en.openfoodfacts.org/product/0000...
#
#            creator   created_t      created_datetime last_modified_t  \
# 0  date-limite-app  1447004364  2015-11-08T17:39:24Z      1447004364
# 1  date-limite-app  1434530704  2015-06-17T08:45:04Z      1434535914
#
#   last_modified_datetime            product_name generic_name quantity  \
# 0   2015-11-08T17:39:24Z  Poêlée à la sarladaise          NaN      NaN
# 1   2015-06-17T10:11:54Z           Filet de bœuf          NaN  2.46 kg
#
#       packaging packaging_tags brands brands_tags     categories  \
# 0  plat cuisiné   plat-cuisine    NaN         NaN            NaN
# 1     plastique      plastique    NaN         NaN  Filet de bœuf
#
#      categories_tags      categories_en origins origins_tags  \
# 0                NaN                NaN     NaN          NaN
# 1  fr:filet-de-boeuf  fr:Filet-de-boeuf     NaN          NaN
#
#   manufacturing_places manufacturing_places_tags labels labels_tags labels_en  \
# 0                  NaN                       NaN    NaN         NaN       NaN
# 1                  NaN                       NaN    NaN         NaN       NaN
#
#   emb_codes emb_codes_tags first_packaging_code_geo cities cities_tags  \
# 0       NaN            NaN                      NaN    NaN         NaN
# 1       NaN            NaN                      NaN    NaN         NaN
#
#   purchase_places stores countries countries_tags countries_en  \
# 0             NaN    NaN     en:FR      en:france       France
# 1             NaN    NaN    France      en:france       France
#
#   ingredients_text allergens allergens_en traces traces_tags traces_en  \
# 0              NaN       NaN          NaN    NaN         NaN       NaN
# 1              NaN       NaN          NaN    NaN         NaN       NaN
#
#   serving_size  no_nutriments  additives_n additives additives_tags  \
# 0          NaN            NaN          NaN       NaN            NaN
# 1          NaN            NaN          NaN       NaN            NaN
#
#   additives_en  ingredients_from_palm_oil_n  ingredients_from_palm_oil  \
# 0          NaN                          NaN                        NaN
# 1          NaN                          NaN                        NaN
#
#   ingredients_from_palm_oil_tags  ingredients_that_may_be_from_palm_oil_n  \
# 0                            NaN                                      NaN
# 1                            NaN                                      NaN
#
#             ...             starch_100g polyols_100g  fiber_100g  \
# 0           ...                     NaN          NaN         NaN
# 1           ...                     NaN          NaN         NaN
#
#   proteins_100g casein_100g serum_proteins_100g nucleotides_100g salt_100g  \
# 0           NaN         NaN                 NaN              NaN       NaN
# 1           NaN         NaN                 NaN              NaN       NaN
#
#   sodium_100g alcohol_100g vitamin_a_100g beta_carotene_100g vitamin_d_100g  \
# 0         NaN          NaN            NaN                NaN            NaN
# 1         NaN          NaN            NaN                NaN            NaN
#
#    vitamin_e_100g  vitamin_k_100g  vitamin_c_100g  vitamin_b1_100g  \
# 0             NaN             NaN             NaN              NaN
# 1             NaN             NaN             NaN              NaN
#
#    vitamin_b2_100g  vitamin_pp_100g  vitamin_b6_100g  vitamin_b9_100g  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
#
#    vitamin_b12_100g  biotin_100g  pantothenic_acid_100g  silica_100g  \
# 0               NaN          NaN                    NaN          NaN
# 1               NaN          NaN                    NaN          NaN
#
#    bicarbonate_100g  potassium_100g  chloride_100g  calcium_100g  \
# 0               NaN             NaN            NaN           NaN
# 1               NaN             NaN            NaN           NaN
#
#    phosphorus_100g  iron_100g  magnesium_100g  zinc_100g  copper_100g  \
# 0              NaN        NaN             NaN        NaN          NaN
# 1              NaN        NaN             NaN        NaN          NaN
#
#    manganese_100g  fluoride_100g  selenium_100g  chromium_100g  \
# 0             NaN            NaN            NaN            NaN
# 1             NaN            NaN            NaN            NaN
#
#    molybdenum_100g  iodine_100g  caffeine_100g  taurine_100g  ph_100g  \
# 0              NaN          NaN            NaN           NaN      NaN
# 1              NaN          NaN            NaN           NaN      NaN
#
#    fruits_vegetables_nuts_100g  collagen_meat_protein_ratio_100g  cocoa_100g  \
# 0                          NaN                               NaN         NaN
# 1                          NaN                               NaN         NaN
#
#    chlorophyl_100g  carbon_footprint_100g  nutrition_score_fr_100g  \
# 0              NaN                    NaN                      NaN
# 1              NaN                    NaN                      NaN
#
#    nutrition_score_uk_100g
# 0                      NaN
# 1                      NaN
#
# [2 rows x 159 columns]

# %%
world_food_facts.countries = world_food_facts.countries.str.lower()

# %%
world_food_facts.shape
# Out:
# (65503, 159)

# %%
def mean(l):
    return float(sum(l)) / len(l)

# %%
world_sugars = world_food_facts[world_food_facts.sugars_100g.notnull()]

def return_sugars(country):
    return world_sugars[world_sugars.countries == country].sugars_100g.tolist()

# %%
fr_sugars = return_sugars('france') + return_sugars('en:fr')
za_sugars = return_sugars('south africa')
uk_sugars = return_sugars('united kingdom') + return_sugars('en:gb')
us_sugars = return_sugars('united states') + return_sugars('en:us') + return_sugars('us')
sp_sugars = return_sugars('spain') + return_sugars('españa') + return_sugars('en:es')
nd_sugars = return_sugars('netherlands') + return_sugars('holland')
au_sugars = return_sugars('australia') + return_sugars('en:au')
cn_sugars = return_sugars('canada') + return_sugars('en:cn')
de_sugars = return_sugars('germany')

countries = ['FR', 'ZA', 'UK', 'US', 'ES', 'ND', 'AU', 'CN', 'DE']
sugars_l = [mean(fr_sugars), 
            mean(za_sugars), 
            mean(uk_sugars), 
            mean(us_sugars), 
            mean(sp_sugars), 
            mean(nd_sugars),
            mean(au_sugars),
            mean(cn_sugars),
            mean(de_sugars)]

# %%
y_pos = np.arange(len(countries))

plt.bar(y_pos, sugars_l, align='center', alpha=0.5)
plt.title('Average total sugar content per 100g')
plt.xticks(y_pos, countries)
plt.ylabel('Sugar/100g')
    
plt.show()

# %%
y_pos
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7, 8])
